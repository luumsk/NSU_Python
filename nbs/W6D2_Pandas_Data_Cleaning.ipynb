# %% [markdown]
# # Data Cleaning with Pandas

# %% [markdown]
# A simplified data science process can be broken down into the following straightforward steps:
#
# 1. **Define the Problem**: Clearly state the problem you want to solve using data. Understand the business or research context. Examples:
#     - Recommendation Systems:
#         - Problem: An e-commerce platform wants to increase sales by recommending products to users.
#         - Definition: Define the problem as creating a recommendation system that suggests products to users based on their preferences, browsing history, and purchase behavior.
#         - Data Required: User behavior data (e.g., clicks, purchases, views), product information, user profiles, and possibly contextual data (location, time).
#         - Data Sources: Website and App Usage Analytics, Product Catalogs, User Profiles, and External Contextual Data.
#     - Healthcare Diagnosis:
#         - Problem: A hospital wants to improve early disease detection.
#         - Definition: Frame the problem as developing a predictive model for early diagnosis of diseases based on patient symptoms and medical history.
#         - Data Required: Patient medical records (symptoms, test results, medical history), diagnostic codes, and potentially external data (research papers, clinical trials).
#         - Data Sources: Electronic Health Records (EHR), Lab Results, Imaging Reports, and Medical Literature.
#
#
# 2. **Data Collection**: Gather the data required to address the problem. This might involve databases, spreadsheets, or other sources. Some problems could be:
#     - Inaccurate, incomplete, or inconsistent data can lead to unreliable results.
#     - Data may not be readily available or may exist in various formats and locations, making it challenging to collect and consolidate.
#     - When integrating data from different sources, ensuring data compatibility (e.g., consistent data formats, units, and identifiers) can be challenging.
#     - Collecting and using data may be subject to legal restrictions, contracts, or industry regulations. Ensuring compliance is essential.
#
# 3. **Data Cleaning**: Clean and organize the data. Remove errors, handle missing values, and format it for analysis. (TODAY)
#
# 4. **Data Analysis**: Explore the data to understand its characteristics. This can involve basic statistics and simple visualizations.(NEXT WEEK)
#
# 5. **Model Building**: Choose a straightforward algorithm or method to build a predictive or descriptive model.
#
# 6. **Model Training**: Train your model using the cleaned data. Adjust model settings if needed.
#
# 7. **Model Evaluation**: Assess how well the model performs. Use simple metrics to measure its accuracy.
#
# 8. **Communication**: Share the findings and insights with others, making sure they understand the results.
#
# 9. **Iterate**: If necessary, repeat the process with additional data or make improvements based on feedback.

# %% [markdown]
# ## 1. Handling missing values

# %% [markdown]
# Data cleaning involves identifying and correcting errors, inconsistencies, and inaccuracies in datasets to ensure that the data is of high quality and reliable for analysis. Data cleaning is essential because the accuracy and quality of data significantly impact the validity and effectiveness of any data-driven project.
#
# This section used the [Billionaires Statistic Dataset](https://www.kaggle.com/datasets/nelgiriyewithana/billionaires-statistics-dataset) that contains information about world's billionaies.
#
# Description:
#
# - rank: The ranking of the billionaire in terms of wealth.
# - finalWorth: The final net worth of the billionaire in U.S. dollars.
# - category: The category or industry in which the billionaire's business operates.
# - personName: The full name of the billionaire.
# - age: The age of the billionaire.
# - country: The country in which the billionaire resides.
# - city: The city in which the billionaire resides.
# - source: The source of the billionaire's wealth.
# - industries: The industries associated with the billionaire's business interests.
# - countryOfCitizenship: The country of citizenship of the billionaire.
# - organization: The name of the organization or company associated with the billionaire.
# - selfMade: Indicates whether the billionaire is self-made (True/False).
# - status: "D" represents self-made billionaires (Founders/Entrepreneurs) and "U" indicates inherited or unearned wealth.
# - gender: The gender of the billionaire.
# - birthDate: The birthdate of the billionaire.
# - lastName: The last name of the billionaire.
# - firstName: The first name of the billionaire.
# - title: The title or honorific of the billionaire.
# - date: The date of data collection.
# - state: The state in which the billionaire resides.
# - residenceStateRegion: The region or state of residence of the billionaire.
# - birthYear: The birth year of the billionaire.
# - birthMonth: The birth month of the billionaire.
# - birthDay: The birth day of the billionaire.
# - cpi_country: Consumer Price Index (CPI) for the billionaire's country.
# - cpi_change_country: CPI change for the billionaire's country.
# - gdp_country: Gross Domestic Product (GDP) for the billionaire's country.
# - gross_tertiary_education_enrollment: Enrollment in tertiary education in the billionaire's country.
# - gross_primary_education_enrollment_country: Enrollment in primary education in the billionaire's country.
# - life_expectancy_country: Life expectancy in the billionaire's country.
# - tax_revenue_country_country: Tax revenue in the billionaire's country.
# - total_tax_rate_country: Total tax rate in the billionaire's country.
# - population_country: Population of the billionaire's country.
# - latitude_country: Latitude coordinate of the billionaire's country.
# - longitude_country: Longitude coordinate of the billionaire's country.

# %%
import numpy as np
import pandas as pd

# %%
# Read data from a csv file
df = pd.read_csv("../data/billionairs.csv")

# %%
# Check the shape of data
df.shape
# Out:
# (2640, 35)

# %%
# View first 3 rows
df.head(3)
# Out:
#    rank  finalWorth          category                personName   age  \
# 0     1      211000  Fashion & Retail  Bernard Arnault & family  74.0
# 1     2      180000        Automotive                 Elon Musk  51.0
# 2     3      114000        Technology                Jeff Bezos  59.0
#
#          country    city         source        industries  \
# 0         France   Paris           LVMH  Fashion & Retail
# 1  United States  Austin  Tesla, SpaceX        Automotive
# 2  United States  Medina         Amazon        Technology
#
#   countryOfCitizenship  ... cpi_change_country           gdp_country  \
# 0               France  ...                1.1   $2,715,518,274,227
# 1        United States  ...                7.5  $21,427,700,000,000
# 2        United States  ...                7.5  $21,427,700,000,000
#
#   gross_tertiary_education_enrollment  \
# 0                                65.6
# 1                                88.2
# 2                                88.2
#
#   gross_primary_education_enrollment_country life_expectancy_country  \
# 0                                      102.5                    82.5
# 1                                      101.8                    78.5
# 2                                      101.8                    78.5
#
#   tax_revenue_country_country total_tax_rate_country population_country  \
# 0                        24.2                   60.7         67059887.0
# 1                         9.6                   36.6        328239523.0
# 2                         9.6                   36.6        328239523.0
#
#   latitude_country longitude_country
# 0        46.227638          2.213749
# 1        37.090240        -95.712891
# 2        37.090240        -95.712891
#
# [3 rows x 35 columns]

# %%
# Print all columns of the data
df.columns
# Out:
# Index(['rank', 'finalWorth', 'category', 'personName', 'age', 'country',
#        'city', 'source', 'industries', 'countryOfCitizenship', 'organization',
#        'selfMade', 'status', 'gender', 'birthDate', 'lastName', 'firstName',
#        'title', 'date', 'state', 'residenceStateRegion', 'birthYear',
#        'birthMonth', 'birthDay', 'cpi_country', 'cpi_change_country',
#        'gdp_country', 'gross_tertiary_education_enrollment',
#        'gross_primary_education_enrollment_country', 'life_expectancy_country',
#        'tax_revenue_country_country', 'total_tax_rate_country',
#        'population_country', 'latitude_country', 'longitude_country'],
#       dtype='object')

# %%
# Check missing values by columns
missing_values_count = df.isna().sum()
na_cols = missing_values_count[missing_values_count > 0].sort_values(ascending=False)

print(f"{len(na_cols)} columns contain missing values.")
na_cols
# Out:
# 23 columns contain missing values.
# organization                                  2315
# title                                         2301
# residenceStateRegion                          1893
# state                                         1887
# cpi_country                                    184
# cpi_change_country                             184
# tax_revenue_country_country                    183
# total_tax_rate_country                         182
# life_expectancy_country                        182
# gross_tertiary_education_enrollment            182
# gross_primary_education_enrollment_country     181
# longitude_country                              164
# latitude_country                               164
# population_country                             164
# gdp_country                                    164
# birthYear                                       77
# birthDay                                        76
# birthMonth                                      76
# birthDate                                       76
# city                                            72
# age                                             65
# country                                         38
# firstName                                        3
# dtype: int64

# %%
df.isna().sum().sum() / df.size * 100
# Out:
# 11.702380952380953

# %%
# how many total missing values do we have?
total_cells = df.size
total_missing = missing_values_count.sum()

# percent of data that is missing
percent_missing = (total_missing/total_cells) * 100
print(f"{percent_missing:.2f}% of data is missing.")
# Out:
# 11.70% of data is missing.

# %% [markdown]
# **Data Intuition**
#
# Is the data missing because it does not exist or it is not recorded?
# - If it does not exist, for example, current salary of a housewife who does not have a paying job, or year of college graduation of a person who has never study at a college. It's better leave it as missing. Attempting to guess a value is not meaningful.
# - If the data is not recorded but you can guess what value could have been based on other values in the same row or the same column, you can fill missing values with a guessed value. This is called `imputation`.

# %% [markdown]
# Some techniques to handle missing data

# %% [markdown]
# 1. Drop missing values

# %%
# drop a row if there is any missing value in that row
dropped_na_df = df.dropna()
dropped_na_df.shape
# Out:
# (238, 35)

# %%
# drop a column if there is any missing value in that column
dropped_na_df = df.dropna(axis=1)
print(dropped_na_df.shape)
print(dropped_na_df.isna().sum().sum())
dropped_na_df.head()
# Out:
# (2640, 12)
# 0
#    rank  finalWorth               category                personName  \
# 0     1      211000       Fashion & Retail  Bernard Arnault & family
# 1     2      180000             Automotive                 Elon Musk
# 2     3      114000             Technology                Jeff Bezos
# 3     4      107000             Technology             Larry Ellison
# 4     5      106000  Finance & Investments            Warren Buffett
#
#                source             industries countryOfCitizenship  selfMade  \
# 0                LVMH       Fashion & Retail               France     False
# 1       Tesla, SpaceX             Automotive        United States      True
# 2              Amazon             Technology        United States      True
# 3              Oracle             Technology        United States      True
# 4  Berkshire Hathaway  Finance & Investments        United States      True
#
#   status gender lastName        date
# 0      U      M  Arnault  23/07/2023
# 1      D      M     Musk  22/06/2023
# 2      D      M    Bezos  06/10/2023
# 3      U      M  Ellison  17/09/2023
# 4      D      M  Buffett  21/06/2023

# %% [markdown]
# 2. Fill missing values manually

# %%
df[["personName", "firstName", "lastName"]]
# Out:
#                     personName firstName   lastName
# 0     Bernard Arnault & family   Bernard    Arnault
# 1                    Elon Musk      Elon       Musk
# 2                   Jeff Bezos      Jeff      Bezos
# 3                Larry Ellison     Larry    Ellison
# 4               Warren Buffett    Warren    Buffett
# ...                        ...       ...        ...
# 2635                   Yu Rong      Rong         Yu
# 2636    Richard Yuengling, Jr.   Richard  Yuengling
# 2637             Zhang Gongyun   Gongyun      Zhang
# 2638    Zhang Guiping & family   Guiping      Zhang
# 2639               Inigo Zobel     Inigo      Zobel
#
# [2640 rows x 3 columns]

# %%
# personName is the fullname, we want infer missing firstName from personName
# First, check why the name is missing
df[df["firstName"].isna()][["personName", "firstName", "lastName"]]
# Out:
#           personName firstName lastName
# 676   Tahir & family       NaN    Tahir
# 1240           Jay-Z       NaN    Jay-Z
# 2095         Rihanna       NaN  Rihanna

# %%
# Check where birthYear is missing but age is presented
df[df["birthYear"].isna() & df["age"].notna()][["birthYear", "age"]]
# Out:
#       birthYear   age
# 423         NaN  53.0
# 902         NaN  53.0
# 904         NaN  53.0
# 913         NaN  53.0
# 1494        NaN  53.0
# 1592        NaN  53.0
# 1759        NaN  53.0
# 1809        NaN  53.0
# 2038        NaN  53.0
# 2069        NaN  53.0
# 2437        NaN  53.0
# 2625        NaN  53.0

# %%
idx = df[df["birthYear"].isna() & df["age"].notna()][["birthYear", "age"]].index
idx
df.loc[idx, "birthYear"]
# Out:
# 423    NaN
# 902    NaN
# 904    NaN
# 913    NaN
# 1494   NaN
# 1592   NaN
# 1759   NaN
# 1809   NaN
# 2038   NaN
# 2069   NaN
# 2437   NaN
# 2625   NaN
# Name: birthYear, dtype: float64

# %%
# Calculate the birthYear from age
# Since this data is collected in 2023, we use 2023 as the current year
def get_birthYear(row):
    return 2023 - row["age"]

df.loc[idx, "birthYear"] = df.loc[idx, :].apply(get_birthYear, axis=1)
df[df["birthYear"].isna() & df["age"].notna()][["birthYear", "age"]]
# Out:
# Empty DataFrame
# Columns: [birthYear, age]
# Index: []

# %% [markdown]
# 3. Fill missing values with a mean/median values

# %%
df1 = pd.DataFrame({
    "age": [13,19,12,16,15,13,None,14,13, None],
    "n_rounds": [5,6,7,8,3,4,5,6,6,8]
})
df1
# Out:
#     age  n_rounds
# 0  13.0         5
# 1  19.0         6
# 2  12.0         7
# 3  16.0         8
# 4  15.0         3
# 5  13.0         4
# 6   NaN         5
# 7  14.0         6
# 8  13.0         6
# 9   NaN         8

# %%
median_age = int(df1["age"].median())
mean_age = round(df1["age"].mean(),0)
print(median_age, mean_age)
# Out:
# 13 14.0

# %%
df1["age"] = df1["age"].fillna(median_age)
df1
# Out:
#     age  n_rounds
# 0  13.0         5
# 1  19.0         6
# 2  12.0         7
# 3  16.0         8
# 4  15.0         3
# 5  13.0         4
# 6  13.0         5
# 7  14.0         6
# 8  13.0         6
# 9  13.0         8

# %% [markdown]
# 4. Fill missing values with a default value

# %%
# Fill in missing organization with string "Unknown"
df["organization"].fillna("Unknown", inplace=True)

# %% [markdown]
# ## 2. Inconsistent data entries

# %%
# Get unique values of countries
df["country"].unique()
# Out:
# array(['France', 'United States', 'Mexico', 'India', 'Spain', 'China',
#        'Canada', 'Germany', 'Switzerland', 'Belgium', 'Hong Kong',
#        'Austria', 'Japan', 'United Kingdom', 'Australia', 'Indonesia',
#        'United Arab Emirates', 'Russia', 'Chile', 'Monaco', 'RF',
#        'Czech Republic', 'Sweden', nan, 'Thailand', 'Uzbekistan',
#        'Singapore', 'Nigeria', 'Israel', 'Italy', 'South Africa',
#        'Brazil', 'Malaysia', 'China ', 'South Korea', 'New Zealand',
#        'Philippines', 'Taiwan', 'Norway', 'Egypt', 'Denmark',
#        'Eswatini (Swaziland)', 'Colombia', 'Netherlands', 'Poland',
#        'Bahamas', 'Ukraine', 'Cayman Islands', 'Greece', 'Turkey',
#        'Argentina', 'Georgia', 'Portugal', 'Kazakhstan', 'Algeria',
#        'Vietnam', 'Latvia', 'Finland', 'Bermuda', 'Luxembourg',
#        'British Virgin Islands', 'Cambodia', 'Lebanon', 'Oman', 'Ireland',
#        'Cyprus', 'Guernsey', 'Liechtenstein', 'P.R.C',
#        'Turks and Caicos Islands', 'Romania', 'Qatar', 'Uruguay', 'Nepal',
#        'Slovakia', 'Morocco', 'Hungary', 'Tanzania', 'Bahrain', 'Peru',
#        'Andorra', 'Armenia'], dtype=object)

# %%
# How many country "RF"?
df[df['country']=="RF"].shape[0]
# Out:
# 7

# %%
# There are 2 names for Russia: "Russia" and "RF"
# We need to change to "Russia"
indices = df[df['country']=="RF"].index
df.loc[indices, "country"] = "Russia"
df[df["country"]=="RF"]
# Out:
# Empty DataFrame
# Columns: [rank, finalWorth, category, personName, age, country, city, source, industries, countryOfCitizenship, organization, selfMade, status, gender, birthDate, lastName, firstName, title, date, state, residenceStateRegion, birthYear, birthMonth, birthDay, cpi_country, cpi_change_country, gdp_country, gross_tertiary_education_enrollment, gross_primary_education_enrollment_country, life_expectancy_country, tax_revenue_country_country, total_tax_rate_country, population_country, latitude_country, longitude_country]
# Index: []
#
# [0 rows x 35 columns]

# %% [markdown]
# ## 3. Parsing datetime

# %%
df["date"]
# Out:
# 0       23/07/2023
# 1       22/06/2023
# 2       06/10/2023
# 3       17/09/2023
# 4       21/06/2023
#            ...
# 2635    05/05/2023
# 2636    23/09/2023
# 2637    01/09/2023
# 2638    13/02/2023
# 2639    18/06/2023
# Name: date, Length: 2640, dtype: object

# %% [markdown]
# - Check dtype of column `date`

# %%
df["date"].dtype
# Out:
# dtype('O')

# %% [markdown]
# - Check any inconsitent format

# %%
# Get the normal length of the date string
df["date"].str.len()
# Out:
# 0       10
# 1       10
# 2       10
# 3       10
# 4       10
#         ..
# 2635    10
# 2636    10
# 2637    10
# 2638    10
# 2639    10
# Name: date, Length: 2640, dtype: int64

# %%
# Find date string that are not equal normal length
cond1 = df["date"].str.len() < 10
cond2 = df["date"].str.len() > 10
df[cond1 | cond2]["date"]
# Out:
# 450    21/07/2023 22:08
# 523    17/04/2023 01:46
# 775    05/02/2023 02:45
# Name: date, dtype: object

# %%
# Update date string to match
indices = df[cond1 | cond2].index
df.loc[indices, "date"] = df.loc[indices, "date"].str[:10]
df.loc[indices, "date"]
# Out:
# 450    21/07/2023
# 523    17/04/2023
# 775    05/02/2023
# Name: date, dtype: object

# %% [markdown]
# Parse to datetime

# %%
df["date"] = pd.to_datetime(df["date"], format="%d/%m/%Y")
df["date"].dtype
# Out:
# dtype('<M8[ns]')

# %% [markdown]
# Get days, months, years of datetime

# %%
df["date"].dt.day
# Out:
# 0       23
# 1       22
# 2        6
# 3       17
# 4       21
#         ..
# 2635     5
# 2636    23
# 2637     1
# 2638    13
# 2639    18
# Name: date, Length: 2640, dtype: int32

# %% [markdown]
# See strftime derective [here](https://strftime.org/)

# %% [markdown]
# ## 4. Some basic Pandas methods to explore data

# %% [markdown]
# - Get unique values of a column

# %%
df["gender"].unique()
# Out:
# array(['M', 'F'], dtype=object)

# %% [markdown]
# - Get a subset dataframe by a condition

# %%
df[df["city"]=="Hanoi"]
# Out:
#       rank  finalWorth               category       personName   age  country  \
# 650    636        4300            Diversified  Pham Nhat Vuong  54.0  Vietnam
# 1708  1647        1800          Manufacturing   Tran Dinh Long  62.0  Vietnam
# 1938  1905        1500  Finance & Investments      Ho Hung Anh  52.0  Vietnam
#
#        city                      source             industries  \
# 650   Hanoi                 Diversified            Diversified
# 1708  Hanoi                       Steel          Manufacturing
# 1938  Hanoi  Consumer products, banking  Finance & Investments
#
#      countryOfCitizenship  ... cpi_change_country        gdp_country  \
# 650               Vietnam  ...                2.8  $261,921,244,843
# 1708              Vietnam  ...                2.8  $261,921,244,843
# 1938              Vietnam  ...                2.8  $261,921,244,843
#
#      gross_tertiary_education_enrollment  \
# 650                                 28.5
# 1708                                28.5
# 1938                                28.5
#
#      gross_primary_education_enrollment_country life_expectancy_country  \
# 650                                       110.6                    75.3
# 1708                                      110.6                    75.3
# 1938                                      110.6                    75.3
#
#      tax_revenue_country_country total_tax_rate_country population_country  \
# 650                         19.1                   37.6         96462106.0
# 1708                        19.1                   37.6         96462106.0
# 1938                        19.1                   37.6         96462106.0
#
#      latitude_country longitude_country
# 650         14.058324        108.277199
# 1708        14.058324        108.277199
# 1938        14.058324        108.277199
#
# [3 rows x 35 columns]

# %%
df[df["age"] > 95]
# Out:
#       rank  finalWorth               category                   personName  \
# 145    146       11800            Diversified                  Robert Kuok
# 409    405        6300          Manufacturing     Stef Wertheimer & family
# 592    591        4600  Media & Entertainment       Charles Dolan & family
# 1216  1217        2500        Food & Beverage            S. Daniel Abraham
# 1342  1312        2300        Food & Beverage                David Murdock
# 1398  1368        2200  Finance & Investments               Charles Munger
# 1409  1368        2200             Healthcare               Alice Schwartz
# 1941  1905        1500  Finance & Investments          Stephen Jarislowsky
# 2033  2020        1400          Manufacturing                  John Farber
# 2065  2020        1400       Fashion & Retail       Bernard Lewis & family
# 2103  2020        1400       Fashion & Retail          Nobutoshi Shimamura
# 2180  2133        1300  Finance & Investments                George Joseph
# 2327  2259        1200            Diversified              Keshub Mahindra
# 2546  2540        1000            Diversified  Ana Maria Brescia Cafferata
#
#         age         country         city                        source  \
# 145    99.0       Hong Kong    Hong Kong  Palm oil, shipping, property
# 409    96.0          Israel     Tel Aviv            Metalworking tools
# 592    96.0   United States   Oyster Bay              Cable television
# 1216   98.0   United States   Palm Beach                     Slim-Fast
# 1342   99.0   United States      Ventura             Dole, real estate
# 1398   99.0   United States  Los Angeles            Berkshire Hathaway
# 1409   96.0   United States   El Cerrito                       Biotech
# 1941   97.0          Canada     Montreal              Money management
# 2033   97.0   United States     New York                     Chemicals
# 2065   97.0  United Kingdom       London              Fashion retailer
# 2103   97.0           Japan      Saitama                        Retail
# 2180  101.0   United States  Los Angeles                     Insurance
# 2327   99.0           India       Mumbai                   Diversified
# 2546   98.0            Peru         Lima               Mining, banking
#
#                  industries countryOfCitizenship  ... cpi_change_country  \
# 145             Diversified             Malaysia  ...                NaN
# 409           Manufacturing               Israel  ...                0.8
# 592   Media & Entertainment        United States  ...                7.5
# 1216        Food & Beverage        United States  ...                7.5
# 1342        Food & Beverage        United States  ...                7.5
# 1398  Finance & Investments        United States  ...                7.5
# 1409             Healthcare        United States  ...                7.5
# 1941  Finance & Investments               Canada  ...                1.9
# 2033          Manufacturing        United States  ...                7.5
# 2065       Fashion & Retail       United Kingdom  ...                1.7
# 2103       Fashion & Retail                Japan  ...                0.5
# 2180  Finance & Investments        United States  ...                7.5
# 2327            Diversified                India  ...                7.7
# 2546            Diversified                 Peru  ...                2.1
#
#                gdp_country gross_tertiary_education_enrollment  \
# 145                    NaN                                 NaN
# 409      $395,098,666,122                                 63.4
# 592   $21,427,700,000,000                                 88.2
# 1216  $21,427,700,000,000                                 88.2
# 1342  $21,427,700,000,000                                 88.2
# 1398  $21,427,700,000,000                                 88.2
# 1409  $21,427,700,000,000                                 88.2
# 1941   $1,736,425,629,520                                 68.9
# 2033  $21,427,700,000,000                                 88.2
# 2065   $2,827,113,184,696                                 60.0
# 2103   $5,081,769,542,380                                 63.2
# 2180  $21,427,700,000,000                                 88.2
# 2327   $2,611,000,000,000                                 28.1
# 2546     $226,848,050,820                                 70.7
#
#      gross_primary_education_enrollment_country life_expectancy_country  \
# 145                                         NaN                     NaN
# 409                                       104.9                    82.8
# 592                                       101.8                    78.5
# 1216                                      101.8                    78.5
# 1342                                      101.8                    78.5
# 1398                                      101.8                    78.5
# 1409                                      101.8                    78.5
# 1941                                      100.9                    81.9
# 2033                                      101.8                    78.5
# 2065                                      101.2                    81.3
# 2103                                       98.8                    84.2
# 2180                                      101.8                    78.5
# 2327                                      113.0                    69.4
# 2546                                      106.9                    76.5
#
#      tax_revenue_country_country total_tax_rate_country population_country  \
# 145                          NaN                    NaN                NaN
# 409                         23.1                   25.3       9.053300e+06
# 592                          9.6                   36.6       3.282395e+08
# 1216                         9.6                   36.6       3.282395e+08
# 1342                         9.6                   36.6       3.282395e+08
# 1398                         9.6                   36.6       3.282395e+08
# 1409                         9.6                   36.6       3.282395e+08
# 1941                        12.8                   24.5       3.699198e+07
# 2033                         9.6                   36.6       3.282395e+08
# 2065                        25.5                   30.6       6.683440e+07
# 2103                        11.9                   46.7       1.262266e+08
# 2180                         9.6                   36.6       3.282395e+08
# 2327                        11.2                   49.7       1.366418e+09
# 2546                        14.3                   36.8       3.251045e+07
#
#      latitude_country longitude_country
# 145               NaN               NaN
# 409         31.046051         34.851612
# 592         37.090240        -95.712891
# 1216        37.090240        -95.712891
# 1342        37.090240        -95.712891
# 1398        37.090240        -95.712891
# 1409        37.090240        -95.712891
# 1941        56.130366       -106.346771
# 2033        37.090240        -95.712891
# 2065        55.378051         -3.435973
# 2103        36.204824        138.252924
# 2180        37.090240        -95.712891
# 2327        20.593684         78.962880
# 2546        -9.189967        -75.015152
#
# [14 rows x 35 columns]

# %% [markdown]
# - Get a subset dataframe by multiple conditions

# %%
# Female Billionairs who have citizenship of 'Japan'
df[(df["gender"]=="F") & (df["countryOfCitizenship"]=="Japan")]
# Out:
#       rank  finalWorth               category       personName   age country  \
# 2081  2020        1400            Real Estate     Yoshiko Mori  82.0   Japan
# 2083  2020        1400             Healthcare  Tadako Nakatani   NaN   Japan
# 2164  2133        1300  Media & Entertainment    Keiko Erikawa  74.0   Japan
#
#                city                        source             industries  \
# 2081          Tokyo                   Real estate            Real Estate
# 2083           Kobe  Medical diagnostic equipment             Healthcare
# 2164  Yokohama City                   Video games  Media & Entertainment
#
#      countryOfCitizenship  ... cpi_change_country          gdp_country  \
# 2081                Japan  ...                0.5  $5,081,769,542,380
# 2083                Japan  ...                0.5  $5,081,769,542,380
# 2164                Japan  ...                0.5  $5,081,769,542,380
#
#      gross_tertiary_education_enrollment  \
# 2081                                63.2
# 2083                                63.2
# 2164                                63.2
#
#      gross_primary_education_enrollment_country life_expectancy_country  \
# 2081                                       98.8                    84.2
# 2083                                       98.8                    84.2
# 2164                                       98.8                    84.2
#
#      tax_revenue_country_country total_tax_rate_country population_country  \
# 2081                        11.9                   46.7        126226568.0
# 2083                        11.9                   46.7        126226568.0
# 2164                        11.9                   46.7        126226568.0
#
#      latitude_country longitude_country
# 2081        36.204824        138.252924
# 2083        36.204824        138.252924
# 2164        36.204824        138.252924
#
# [3 rows x 35 columns]

# %% [markdown]
# - Get unique values of a subset dataframe

# %%
# City/Cities where all Russian billionaires in "Fashion & Retail" industry reside?
df[(df["country"]=="Russia") & (df["industries"]=="Fashion & Retail")]["city"].unique()
# Out:
# array(['Moscow region', 'Moscow', 'Krasnodar'], dtype=object)

# %% [markdown]
# - Get min, max, mean values of a subset

# %%
# The youngest billionaires on the list
df["age"].min()
# Out:
# 18.0

# %%
# The oldest billionaires reside in "Canada"
df[df["country"]=="Canada"]["age"].max()
# Out:
# 97.0

# %% [markdown]
# ## 5. Handling duplications

# %% [markdown]
# Duplication in data refers to the presence of identical or nearly identical records or rows in a dataset.
#
# **Why are there data duplication?**
#
# - Data Entry Errors: Human errors during data entry, such as double data entry.
# - Data Integration: When data from multiple sources is merged or integrated, it may result in duplicates if there are inconsistencies in data representations.
# - Data Extraction: Automated data extraction processes, like web scraping, may unintentionally capture and store the same data multiple times.
# - Data Processing Errors: Errors in data transformation and preprocessing pipelines can generate duplicate records.
# - Software Bugs: Bugs in data collection or management software can cause unintended duplication.
#
#
# **What are the negetive effects of data duplication?**
#
# Data duplication can have several negative effects for organizations and data-driven processes. These consequences affect data quality, operational efficiency, and decision-making.
#
# - Data Skew: Duplicate records can bias statistical and analytical results, leading to incorrect conclusions and predictions.
# - Increased Storage Costs: Duplicate data consumes extra storage space, increasing operational costs.
# - Complexity: Handling duplicates complicates data management, analysis, and reporting.
# - Reduced Efficiency: Queries and analyses may take longer to complete due to the presence of duplicates.
# - Data Inaccuracy: Duplicates can affect data accuracy and integrity.

# %%
import pandas as pd

# %%
df = pd.read_csv("../data/billionairs.csv")

# add 3 duplications to the end
for i in range(3):
    df.loc[df.shape[0]] = df.iloc[df.shape[0]-1]

# %%
df.tail()
# Out:
#       rank  finalWorth     category              personName   age  \
# 2638  2540        1000  Real Estate  Zhang Guiping & family  71.0
# 2639  2540        1000  Diversified             Inigo Zobel  66.0
# 2640  2540        1000  Diversified             Inigo Zobel  66.0
# 2641  2540        1000  Diversified             Inigo Zobel  66.0
# 2642  2540        1000  Diversified             Inigo Zobel  66.0
#
#           country     city       source   industries countryOfCitizenship  \
# 2638        China  Nanjing  Real estate  Real Estate                China
# 2639  Philippines   Makati  Diversified  Diversified          Philippines
# 2640  Philippines   Makati  Diversified  Diversified          Philippines
# 2641  Philippines   Makati  Diversified  Diversified          Philippines
# 2642  Philippines   Makati  Diversified  Diversified          Philippines
#
#       ... cpi_change_country           gdp_country  \
# 2638  ...                2.9  $19,910,000,000,000
# 2639  ...                2.5     $376,795,508,680
# 2640  ...                2.5     $376,795,508,680
# 2641  ...                2.5     $376,795,508,680
# 2642  ...                2.5     $376,795,508,680
#
#      gross_tertiary_education_enrollment  \
# 2638                                50.6
# 2639                                35.5
# 2640                                35.5
# 2641                                35.5
# 2642                                35.5
#
#      gross_primary_education_enrollment_country life_expectancy_country  \
# 2638                                      100.2                    77.0
# 2639                                      107.5                    71.1
# 2640                                      107.5                    71.1
# 2641                                      107.5                    71.1
# 2642                                      107.5                    71.1
#
#      tax_revenue_country_country total_tax_rate_country population_country  \
# 2638                         9.4                   59.2       1.397715e+09
# 2639                        14.0                   43.1       1.081166e+08
# 2640                        14.0                   43.1       1.081166e+08
# 2641                        14.0                   43.1       1.081166e+08
# 2642                        14.0                   43.1       1.081166e+08
#
#      latitude_country longitude_country
# 2638        35.861660        104.195397
# 2639        12.879721        121.774017
# 2640        12.879721        121.774017
# 2641        12.879721        121.774017
# 2642        12.879721        121.774017
#
# [5 rows x 35 columns]

# %% [markdown]
# Check duplication

# %%
# Check duplication of rows
df.duplicated().sum()
# Out:
# 3

# %%
# Check duplication of values in a column
df.duplicated(subset="rank").sum()
# Out:
# 2424

# %%
# List 10 rank that have most duplication
df["rank"].value_counts().sort_values(ascending=False)[:10]
# Out:
# rank
# 2259    146
# 2405    135
# 2133    126
# 1905    115
# 2020    113
# 2540    104
# 1804    101
# 1434     82
# 1725     79
# 1647     78
# Name: count, dtype: int64

# %% [markdown]
# Drop duplication

# %%
dropped = df.drop_duplicates()
print("Number of duplication:", dropped.duplicated().sum())
dropped.tail(3)
# Out:
# Number of duplication: 0
#       rank  finalWorth       category              personName   age  \
# 2637  2540        1000  Manufacturing           Zhang Gongyun  60.0
# 2638  2540        1000    Real Estate  Zhang Guiping & family  71.0
# 2639  2540        1000    Diversified             Inigo Zobel  66.0
#
#           country     city                        source     industries  \
# 2637        China    Gaomi  Tyre manufacturing machinery  Manufacturing
# 2638        China  Nanjing                   Real estate    Real Estate
# 2639  Philippines   Makati                   Diversified    Diversified
#
#      countryOfCitizenship  ... cpi_change_country           gdp_country  \
# 2637                China  ...                2.9  $19,910,000,000,000
# 2638                China  ...                2.9  $19,910,000,000,000
# 2639          Philippines  ...                2.5     $376,795,508,680
#
#      gross_tertiary_education_enrollment  \
# 2637                                50.6
# 2638                                50.6
# 2639                                35.5
#
#      gross_primary_education_enrollment_country life_expectancy_country  \
# 2637                                      100.2                    77.0
# 2638                                      100.2                    77.0
# 2639                                      107.5                    71.1
#
#      tax_revenue_country_country total_tax_rate_country population_country  \
# 2637                         9.4                   59.2       1.397715e+09
# 2638                         9.4                   59.2       1.397715e+09
# 2639                        14.0                   43.1       1.081166e+08
#
#      latitude_country longitude_country
# 2637        35.861660        104.195397
# 2638        35.861660        104.195397
# 2639        12.879721        121.774017
#
# [3 rows x 35 columns]

# %% [markdown]
# Drop using `keep` parameter

# %%
# Keep the first row in the duplications
dropped_keep_first = df.drop_duplicates(keep="first")
dropped_keep_first.tail(3)
# Out:
#       rank  finalWorth       category              personName   age  \
# 2637  2540        1000  Manufacturing           Zhang Gongyun  60.0
# 2638  2540        1000    Real Estate  Zhang Guiping & family  71.0
# 2639  2540        1000    Diversified             Inigo Zobel  66.0
#
#           country     city                        source     industries  \
# 2637        China    Gaomi  Tyre manufacturing machinery  Manufacturing
# 2638        China  Nanjing                   Real estate    Real Estate
# 2639  Philippines   Makati                   Diversified    Diversified
#
#      countryOfCitizenship  ... cpi_change_country           gdp_country  \
# 2637                China  ...                2.9  $19,910,000,000,000
# 2638                China  ...                2.9  $19,910,000,000,000
# 2639          Philippines  ...                2.5     $376,795,508,680
#
#      gross_tertiary_education_enrollment  \
# 2637                                50.6
# 2638                                50.6
# 2639                                35.5
#
#      gross_primary_education_enrollment_country life_expectancy_country  \
# 2637                                      100.2                    77.0
# 2638                                      100.2                    77.0
# 2639                                      107.5                    71.1
#
#      tax_revenue_country_country total_tax_rate_country population_country  \
# 2637                         9.4                   59.2       1.397715e+09
# 2638                         9.4                   59.2       1.397715e+09
# 2639                        14.0                   43.1       1.081166e+08
#
#      latitude_country longitude_country
# 2637        35.861660        104.195397
# 2638        35.861660        104.195397
# 2639        12.879721        121.774017
#
# [3 rows x 35 columns]

# %%
# Keep the last row in the duplications
dropped_keep_first = df.drop_duplicates(keep="last")
dropped_keep_first.tail(3)
# Out:
#       rank  finalWorth       category              personName   age  \
# 2637  2540        1000  Manufacturing           Zhang Gongyun  60.0
# 2638  2540        1000    Real Estate  Zhang Guiping & family  71.0
# 2642  2540        1000    Diversified             Inigo Zobel  66.0
#
#           country     city                        source     industries  \
# 2637        China    Gaomi  Tyre manufacturing machinery  Manufacturing
# 2638        China  Nanjing                   Real estate    Real Estate
# 2642  Philippines   Makati                   Diversified    Diversified
#
#      countryOfCitizenship  ... cpi_change_country           gdp_country  \
# 2637                China  ...                2.9  $19,910,000,000,000
# 2638                China  ...                2.9  $19,910,000,000,000
# 2642          Philippines  ...                2.5     $376,795,508,680
#
#      gross_tertiary_education_enrollment  \
# 2637                                50.6
# 2638                                50.6
# 2642                                35.5
#
#      gross_primary_education_enrollment_country life_expectancy_country  \
# 2637                                      100.2                    77.0
# 2638                                      100.2                    77.0
# 2642                                      107.5                    71.1
#
#      tax_revenue_country_country total_tax_rate_country population_country  \
# 2637                         9.4                   59.2       1.397715e+09
# 2638                         9.4                   59.2       1.397715e+09
# 2642                        14.0                   43.1       1.081166e+08
#
#      latitude_country longitude_country
# 2637        35.861660        104.195397
# 2638        35.861660        104.195397
# 2642        12.879721        121.774017
#
# [3 rows x 35 columns]

# %%
# Remove the all duplications
dropped_keep_first = df.drop_duplicates(keep=False)
dropped_keep_first.tail(3)
# Out:
#       rank  finalWorth         category              personName   age  \
# 2636  2540        1000  Food & Beverage  Richard Yuengling, Jr.  80.0
# 2637  2540        1000    Manufacturing           Zhang Gongyun  60.0
# 2638  2540        1000      Real Estate  Zhang Guiping & family  71.0
#
#             country        city                        source  \
# 2636  United States  Pottsville                          Beer
# 2637          China       Gaomi  Tyre manufacturing machinery
# 2638          China     Nanjing                   Real estate
#
#            industries countryOfCitizenship  ... cpi_change_country  \
# 2636  Food & Beverage        United States  ...                7.5
# 2637    Manufacturing                China  ...                2.9
# 2638      Real Estate                China  ...                2.9
#
#                gdp_country gross_tertiary_education_enrollment  \
# 2636  $21,427,700,000,000                                 88.2
# 2637  $19,910,000,000,000                                 50.6
# 2638  $19,910,000,000,000                                 50.6
#
#      gross_primary_education_enrollment_country life_expectancy_country  \
# 2636                                      101.8                    78.5
# 2637                                      100.2                    77.0
# 2638                                      100.2                    77.0
#
#      tax_revenue_country_country total_tax_rate_country population_country  \
# 2636                         9.6                   36.6       3.282395e+08
# 2637                         9.4                   59.2       1.397715e+09
# 2638                         9.4                   59.2       1.397715e+09
#
#      latitude_country longitude_country
# 2636         37.09024        -95.712891
# 2637         35.86166        104.195397
# 2638         35.86166        104.195397
#
# [3 rows x 35 columns]
